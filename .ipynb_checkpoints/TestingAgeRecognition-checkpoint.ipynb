# %%
import sys
import os
import shutil
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from sklearn.metrics import mean_squared_error, mean_absolute_error
import matplotlib.pyplot as plt
import pandas as pd
from PIL import Image
import numpy as np
import ast
from keras.preprocessing.image import load_img

# %%
# Parameters
current_directory = os.getcwd()

# Name of the model to be evaluated
model_name = 'AgeRecognitionModel_v111.keras'

# Name of the directory in which files with test results will be saved
evaluation_directory_name = 'eval-test'

# Path to the directory where txt files with results will be saved
evaluation_directory_path = os.path.join(current_directory, evaluation_directory_name)

# Name of the file with the data for each image
eval_file_name = 'evaluation.txt'

# Name of the file with the result data
result_file_name = 'result.txt'

# Path to the folder containing images to be used for testing purposes
images_path = 'C:\\Users\\User\\Desktop\\Szkoła\\MachineLearning\\AgeRecognition\\Test'

# Parameter defining whether model predicted age accurately - absolute value of difference between labelled age and predicted age
accuracy_param = 7

# Parameter defining whether the accuracy should be checked in relation to the percentage difference or difference between labelled age and predicted age
accuracy_in_percentage = False

# Size of the age group, ex. for age_group_size = 10, the age groups will be [0-9, 10-19, ...] 
age_group_size = 10

# Name of the residuals histogram
residual_histogram_name = 'residuals_histogram.png'

# Name of the RMSE & MAPE plot
rmse_mape_plot_name = 'RMSE_MAPE.png'

# %%
# Load the pre-trained model
model_path = os.path.join(current_directory, model_name)
model = load_model(model_path)

# Residuals
residuals = []

# %%
import cv2
import numpy as np
from keras.preprocessing import image

def canny_edge_detection(image):
    # Konwersja obrazu na skale szarości
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    
    # Zastosowanie detekcji krawędzi Canny
    edges = cv2.Canny(gray_image, threshold1=30, threshold2=100)
    
    return edges

def create_directory(path, eval_file_name, result_file_name):
    if not os.path.exists(path):
        os.makedirs(path)
        print(f"Created directory at path: {path}")
    
    eval_file_path = os.path.join(path, eval_file_name)
    if os.path.exists(eval_file_path):
        try:
            with open(eval_file_path, 'w') as new_file:
                pass
        except Exception as e:
            print(f"An error occurred: {e}")
            
    result_file_path = os.path.join(path, result_file_name)
    if os.path.exists(result_file_path):
        try:
            with open(result_file_path, 'w') as new_file:
                pass
        except Exception as e:
            print(f"An error occurred: {e}")

def write_to_text_file(dir_path, file_name, content):
    file_path = os.path.join(dir_path, file_name)

    if os.path.exists(file_path):
        with open(file_path, 'a') as file:
            file.write(content + '\n')
    else:
        with open(file_path, 'w') as file:
            file.write(content + '\n')

def get_image_features(image_path):
    img = image.load_img(image_path)
    img = img.resize((200, 200), Image.LANCZOS)
    img = np.array(img)
    img = canny_edge_detection(img)
    img = img.reshape(1, 200, 200, 3)
    img = img / 255.0
    return img

# specific logic for data from: https://www.kaggle.com/datasets/rashikrahmanpritom/age-recognition-dataset
# or other images that contains labelled age in the format: AGE_x_y_z.jpg (age must be in the first index separated by '_' sign)
def eval_image(image_file, dir_path, model, eval_dir, accuracy_param):
    img = get_image_features(os.path.join(dir_path, image_file))

    predictions = model.predict(img)
    age = round(predictions[0][0])

    splitted_text = image_file.split('_')
    labelled_age = int(splitted_text[0])
    difference = abs(labelled_age - age)
    percent_difference = abs(int(difference)) / labelled_age * 100
    is_accurate = round(percent_difference) <= accuracy_param if accuracy_in_percentage else round(difference) <= accuracy_param

    eval_file_name = 'evaluation.txt'
    obj = {
        'Model': age,
        'Label': labelled_age,
        'Difference': difference,
        'PercentageDifference': round(percent_difference),
        'Accurate': is_accurate
    }
    labeled_age = obj['Label']
    predicted_age = obj['Model']
    residuals.append(labeled_age - predicted_age)
    write_to_text_file(eval_dir, eval_file_name, str(obj))

def test_images(directory_path, model, eval_dir, accuracy_param):
    if not os.path.exists(directory_path) or not os.path.isdir(directory_path):
        print(f"The specified path '{directory_path}' is not a valid directory.")
        return
    
    files = os.listdir(directory_path)
    
    image_files = [file for file in files if file.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    if not image_files:
        print(f"No image files found in '{directory_path}'.")
        return
    
    for image_file in image_files:
        try:
            eval_image(image_file, directory_path, model, eval_dir, accuracy_param)
        except Exception as e:
            print(f"Error processing {image_file}. Reason: {e}")

def read_residuals(file_path):
    with open(file_path, 'r') as file:
        lines = file.readlines()

    results = [ast.literal_eval(line.strip()) for line in lines]
    # Calculate residuals and append to the list
    residuals = []
    for result in results:
        labeled_age = result['Label']
        predicted_age = result['Model']
        residuals.append(labeled_age - predicted_age)
    return residuals

# %%
def plot_residual_histogram(residuals, save_path=None):
    plt.figure(figsize=(8, 6))
    plt.hist(residuals, bins=30, edgecolor='black', alpha=0.7)
    plt.title('Residuals Histogram')
    plt.xlabel('Residuals')
    plt.ylabel('Count')

    if save_path:
        plt.savefig(save_path)
    else:
        plt.show()

def analyze_and_visualize_data(eval_dir, file_path, residuals):
    data_file = os.path.join(eval_dir, file_path)
    if not os.path.exists(data_file):
        print(f'There is no such a file at the path: {data_file}')
        print('Run test_images in order to evaluate the dataset')
        return
    
    with open(data_file, 'r') as file:
        lines = file.readlines()

    data_str = ''.join(lines).replace('\n', ',')

    data_list = eval('[' + data_str + ']')

    df = pd.DataFrame(data_list)

    # Calculate RMSE and MAPE for all data in the dataset
    rmse_all = np.sqrt(mean_squared_error(df['Label'], df['Model']))
    mape_all = np.mean(np.abs((df['Model'] - df['Label']) / df['Label'])) * 100

    print("RMSE for all data:", rmse_all)
    print("MAPE for all data:", mape_all)

    age_ranges = list(range(0, 111, age_group_size))
    age_labels = [f"{start}-{start+age_group_size-1}" for start in age_ranges[:-1]]

    df['AgeGroup'] = pd.cut(df['Label'], bins=age_ranges, labels=age_labels, right=False)

    rmse_groups = []
    mape_groups = []

    for age_group in age_labels:
        group = df[df['AgeGroup'] == age_group]

        if group.empty:
            rmse_groups.append(0)
            mape_groups.append(0)
            continue

        rmse_group = np.sqrt(mean_squared_error(group['Label'], group['Model']))
        mape_group = np.mean(np.abs((group['Model'] - group['Label']) / group['Label'])) * 100
        rmse_groups.append(rmse_group)
        mape_groups.append(mape_group)
        print(f"\nRMSE for age group {age_group}:", rmse_group)
        print(f"MAPE for age group {age_group}:", mape_group)

    count_per_age_group = df['AgeGroup'].value_counts().sort_index()

    correct_predictions = df[df['Accurate'] == True].shape[0]
    total_predictions = df.shape[0]
    accuracy = correct_predictions / total_predictions * 100

    print("\nAccuracy:", accuracy, "%")

    results_dict = {
        'RMSE_all': rmse_all,
        'MAPE_all': mape_all,
        'RMSE_groups': rmse_groups,
        'MAPE_groups': mape_groups,
        'Accuracy': accuracy
    }

    result_file_path = os.path.join(eval_dir, result_file_name)
    with open(result_file_path, 'w') as results_file:
        results_file.write(str(results_dict))

    labels = [str(age_group) for age_group in age_labels]

    # Plot and save the residuals histogram
    if not residuals:
        residuals_file_path = os.path.join(eval_dir, eval_file_name)
        if not os.path.exists(residuals_file_path):
            print(f"Error with file at path: {residuals_file_path}")
            print("There is no file containing data for each image. Run test_images")
            return
        
        residuals = read_residuals(residuals_file_path)
    histogram_save_path = os.path.join(eval_dir, residual_histogram_name)
    if not os.path.exists(eval_dir):
        print('Path to save the RMSE & MAPE plot is not proper')
        return
    plot_residual_histogram(residuals, save_path=histogram_save_path)

    plt.figure(figsize=(16, 6))

    # RMSE plot for age groups
    plt.subplot(2, 2, 1)
    plt.bar(labels, rmse_groups, color='blue')
    plt.title('RMSE for Age Groups')
    plt.xlabel('Age Groups')
    plt.ylabel('RMSE')

    # MAPE plot for age groups
    plt.subplot(2, 2, 2)
    plt.bar(labels, mape_groups, color='orange')
    plt.title('MAPE for Age Groups')
    plt.xlabel('Age Groups')
    plt.ylabel('MAPE')

    # Number of people in each age group plot
    plt.subplot(2, 2, 3)
    plt.bar(count_per_age_group.index, count_per_age_group.values, color='gray')
    plt.title('Number of Observations in Each Age Group')
    plt.xlabel('Age Groups')
    plt.ylabel('Count')

    # Accuracy pie plot
    plt.subplot(2, 2, 4)
    plt.pie([correct_predictions, total_predictions - correct_predictions], labels=['Correct', 'Incorrect'], autopct='%1.1f%%', colors=['green', 'red'])
    plt.title(f'Accuracy of Predictions for param: {accuracy_param}')

    plt.tight_layout()

    plot_image_path = os.path.join(eval_dir, rmse_mape_plot_name)
    if not os.path.exists(eval_dir):
        print('Path to save the RMSE & MAPE plot is not proper')
        return
    plt.savefig(plot_image_path)

    plt.show()

# %%
# Create directory or remove its content to save data
create_directory(evaluation_directory_path, eval_file_name, result_file_name)
# Evaluate test images using provided model 
test_images(images_path, model, evaluation_directory_path, accuracy_param)
# Out:
# Error processing 10_0_0_20170110220235233.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170110220557169.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170110224402264.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170110225451638.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170110225546130.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170116201337172.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_0_20170117143048181.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_1_20170110220507258.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_1_20170110225121326.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_3_20161220215952636.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_4_20170103201924664.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_0_4_20170103202338152.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_1_0_20170109203512075.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_1_0_20170109204148144.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_1_0_20170109204255055.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_1_0_20170109204617417.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 10_1_0_20170109205208368.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 110_0_2_20170112223734562.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_0_0_20170110220518578.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_0_0_20170110224755272.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_0_0_20170110225327724.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_0_0_20170110232511893.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_0_2_20170103200847287.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_0_20170109204030951.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_0_20170109204611305.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_0_20170109204927071.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_0_20170109205122664.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_0_20170109205125500.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 11_1_2_20170104005111615.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_0_0_20170103200900511.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_0_0_20170109213205384.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_0_0_20170117165940524.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_0_0_20170117190914091.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170103200944175.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170104013410523.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170109200926532.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170109203338340.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170109205043077.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_0_20170117154622148.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_1_20170109214204794.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_1_20170116233629728.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_2_20170103200649030.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_2_20170104012405785.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_2_20170117194013371.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_4_20161223230033380.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 12_1_4_20170117201252893.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_0_0_20170110224337867.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_0_0_20170110224531616.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_0_2_20170103201417686.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_1_0_20170109204055232.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_1_0_20170109214314841.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_1_0_20170109214402325.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 13_1_0_20170110224453650.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_0_20170102234854353.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_0_20170110224519294.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_0_20170110225056665.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_0_20170110225725643.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_0_20170110232745742.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_1_20170110232707718.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_1_20170116205529704.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_2_20170103200642238.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_2_20170104013318514.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_2_20170110232701995.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_0_3_20170104225245755.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109203638205.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109213221821.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109213635068.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109214345916.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109214349442.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_0_20170109214440556.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_2_20170104013310115.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_3_20170104221818294.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_3_20170104222437734.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 14_1_4_20170103200753206.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170102234355667.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170103201110847.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110224324459.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110225410802.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110225705232.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110232331351.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110232338801.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110232610061.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170110232655904.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170116201246071.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170116201253769.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0_0_20170116201332456.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 15_0
jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 84_1_0_20170120230257434.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_0_0_20170111205438305.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_0_0_20170111210445676.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_0_0_20170111223921971.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_0_0_20170120221827893.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_0_2_20170111221734101.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110173744770.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110181049060.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110181543448.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110181934936.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110182138154.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110182139534.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110182404089.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110182945927.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110183455199.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110183522560.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110183559248.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110183611657.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170110183711497.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170120140054880.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170120222635457.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_0_20170120223641413.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_1_20170120223737998.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_2_20170110183021416.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_2_20170110183509553.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_2_20170120230102370.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 85_1_3_20170110181547340.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 86_0_2_20170112224559130.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 86_1_2_20170105174813405.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 86_1_2_20170110132518353.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 86_1_2_20170112224133563.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 87_1_0_20170110181045529.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 88_0_0_20170113185121024.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 88_1_0_20170105174941006.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 88_1_0_20170110132552849.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 88_1_0_20170120230330380.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 88_1_1_20170116233427954.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_0_1_20170117182437361.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_0_20170110183554182.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_0_20170120134913783.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_0_20170120230308115.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_0_20170120230445570.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_1_20170116160717022.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_2_20170110182930160.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 89_1_3_20170110182042731.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_0_0_20170117175648380.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_0_0_20170117182551223.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_0_4_20170117133054476.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109202308260.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109203324490.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109203407112.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109203557851.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109203602997.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109204534346.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109205108577.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_0_20170109205428806.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_2_20170109203443934.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_2_20170116194013325.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_3_20170104221650071.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_4_20170109201742209.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 8_1_4_20170109202358152.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111205657119.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111210403969.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111211204031.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111211332406.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111222243901.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_0_20170111222418306.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_0_1_20170111205407457.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_0_20170110175738208.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_0_20170110182910242.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_0_20170110183406830.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_0_20170120221911645.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_0_20170120224954568.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 90_1_1_20170117195305990.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 93_1_0_20170120225257592.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 95_1_0_20170120230149594.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 95_1_2_20170110182531150.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 96_1_0_20170110182433943.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 96_1_2_20170105174624519.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 99_1_0_20170120133837030.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 99_1_2_20170117195405372.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110215453036.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110215516060.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110220005370.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110220232058.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110220442681.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110220449969.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_0_20170110224610119.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_1_20170110215449668.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_1_20170110215500987.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_2_20161219192701323.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_0_3_20170104225726769.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_1_0_20170109204754719.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_1_0_20170110224621441.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)
# Error processing 9_1_4_20170103200814791.jpg.chip.jpg. Reason: cannot reshape array of size 36000 into shape (1,200,200,3)

# %%
# Analyze and visualize data from the file located at evaluation_directory_path/eval_file_name
analyze_and_visualize_data(evaluation_directory_path, eval_file_name, residuals)
# Out:
# RMSE for all data: 11.346561837320888
# MAPE for all data: 46.232943078289736
#
# RMSE for age group 0-9: 8.666437725913852
# MAPE for age group 0-9: 197.4139536767088
#
# RMSE for age group 10-19: 10.52968876794268
# MAPE for age group 10-19: 55.611706591720534
#
# RMSE for age group 20-29: 9.227179692106496
# MAPE for age group 20-29: 28.051576028400994
#
# RMSE for age group 30-39: 9.318696005241035
# MAPE for age group 30-39: 21.468518108707293
#
# RMSE for age group 40-49: 10.72220659592578
# MAPE for age group 40-49: 19.810336561960316
#
# RMSE for age group 50-59: 10.953337836298923
# MAPE for age group 50-59: 16.340285927967948
#
# RMSE for age group 60-69: 12.40614247596813
# MAPE for age group 60-69: 16.14585040907682
#
# RMSE for age group 70-79: 15.156278103724766
# MAPE for age group 70-79: 16.198197073781166
#
# RMSE for age group 80-89: 17.546801529123165
# MAPE for age group 80-89: 17.040100274351094
#
# RMSE for age group 90-99: 21.70483817032507
# MAPE for age group 90-99: 20.40327403920358
#
# Accuracy: 53.510436432637576 %
