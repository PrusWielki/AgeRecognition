# %%
import tensorflow as tf
from tensorflow.keras.utils import load_img
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
import numpy as np
import random
import matplotlib.pyplot as plt
import os 
#import seaborn as sns
import warnings 
from tqdm.notebook import tqdm 
import pandas as pd 
import gc
# %matplotlib inline

# %%
BASE_DIR = 'C:\\Users\\kacpe\\OneDrive\\Pulpit\\Uczelnia\\semestr5\\MachineLearning\\UTKFaceNew\\UTKFace'

# %%
from linear_distribution_images import delete_photos_linear

# %%
train_labels = []
train_paths = []

train_filenames = os.listdir(os.path.join(BASE_DIR, "Train"))
random.shuffle(train_filenames)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[15], line 7
#       4 train_filenames = os.listdir(os.path.join(BASE_DIR, "Train"))
#       5 random.shuffle(train_filenames)
# ----> 7 train_filenames[0]
#
# IndexError: list index out of range

# %%
val_labels = []
val_paths = []

val_filenames = os.listdir(os.path.join(BASE_DIR, "Val"))
random.shuffle(val_filenames)

val_filenames[0]
# Out:
# '40_augmented_1_40_0_0_20170117130926545.jpg.chip.jpg'

# %%
test_labels = []
test_paths = []

test_filenames = os.listdir(os.path.join(BASE_DIR, "Test"))
random.shuffle(test_filenames)

test_filenames[0]
# Out:
# '16_augmented_5_16_1_4_20170103233406635.jpg.chip.jpg'

# %%
def get_paths_and_labels(image_filenames, age_labels, image_paths, folder):
    for image in tqdm(image_filenames):
        image_path = os.path.join(BASE_DIR, folder, image)
        img_components = image.split('_')
    
        if img_components[0] == '.ipynb':
            continue
        age_label = int(img_components[0])
        
        # Append the image_path, age_label, and gender_label
        age_labels.append(age_label)
        image_paths.append(image_path)

# %%
get_paths_and_labels(train_filenames, train_labels, train_paths, "Train")
get_paths_and_labels(val_filenames, val_labels, val_paths, "Val")
get_paths_and_labels(test_filenames, test_labels, test_paths, "Test")
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
print(f'Number of age_labels: {len(train_labels)}, Number of image_paths: {len(train_paths)}')
# Out:
# Number of age_labels: 20000, Number of image_paths: 20000

# %%
train_df = pd.DataFrame()
train_df['image_path'], train_df['age'] = train_paths, train_labels
train_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   31
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   52
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   65
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   37
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   22

# %%
val_df = pd.DataFrame()
val_df['image_path'], val_df['age'] = val_paths, val_labels
val_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   40
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   63
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   50
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   15
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   16

# %%
test_df = pd.DataFrame()
test_df['image_path'], test_df['age'] = test_paths, test_labels
test_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   16
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   30
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...    1
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...    1
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\Aug...   57

# %%
from PIL import Image

rand_index = random.randint(0, len(val_paths))
age = val_df['age'][rand_index]
IMG = Image.open(val_df['image_path'][rand_index])
plt.title(f'Age: {age}')
plt.axis('off')
plt.imshow(IMG)

# %%
del train_paths, train_labels, val_paths, val_labels, test_paths, test_labels
gc.collect()
# Out:
# 9

# %%
plt.figure(figsize=(20, 20))
samples = train_df.iloc[0:16]

for index, sample, age in samples.itertuples():
    plt.subplot(4, 4, index + 1)
    img = load_img(sample)
    img = np.array(img)
    plt.axis('off')
    plt.title(f'Age: {age}')
    plt.imshow(img)

# %%
import cv2
import numpy as np

def sobel_edge_detection(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_RGB2GRAY)
    sobel_x = cv2.Sobel(gray_image, cv2.CV_64F, 1, 0, ksize=5)
    sobel_y = cv2.Sobel(gray_image, cv2.CV_64F, 0, 1, ksize=5)
    abs_sobel_x = cv2.convertScaleAbs(sobel_x)
    abs_sobel_y = cv2.convertScaleAbs(sobel_y)
    return cv2.addWeighted(abs_sobel_x, 0.5, abs_sobel_y, 0.5, 0)

# %%
input_width = 180
input_height = 180

# %%
def extract_image_features(images):
    features = list()

    for image in tqdm(images):
        img = load_img(image, color_mode = "rgb")
        img = img.resize((180, 180), Image.LANCZOS)
        img = np.array(img)
        img = sobel_edge_detection(img)
        features.append(img)

    features = np.array(features)
    features = features.reshape(len(features), 180, 180, 3)
    return features

# %%
X_train = extract_image_features(train_df['image_path'], input_width, input_height)
X_val = extract_image_features(val_df['image_path'], input_width, input_height)
X_test = extract_image_features(test_df['image_path'], input_width, input_height)
# Out:
#   0%|          | 0/20000 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]
#   0%|          | 0/4000 [00:00<?, ?it/s]

# %%
y_age_train = np.array(train_df['age'])
y_age_val = np.array(val_df['age'])
y_age_test = np.array(test_df['age'])

# %%
del train_df, val_df, test_df
gc.collect()
# Out:
# 37814

# %%
X_train.shape
# Out:
# (20000, 170, 170, 3)

# %%
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
input_shape = (input_width, input_height, 3)

# %%
inputs = Input((input_shape))
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
max_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(max_1)
max_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(max_2)
max_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
conv_4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(max_3)
max_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)

flatten = Flatten()(max_4)

dense = Dense(256, activation='relu')(flatten)
dropout = Dropout(0.3)(dense)

output = Dense(1, activation='relu', name='age_out')(dropout)

model = Model(inputs=[inputs], outputs=[output])

model.compile(loss='mae',
              optimizer='adam', metrics=['accuracy'])

# mlflow.log_metric("test_rmse", 10) # error
# mlflow.sklearn.log_model(model, "models")

# %%
model = load_model('AgeRecognitionModel_v3.keras')

# %%
history = model.fit(x=X_train, y=y_age_train,
                    batch_size=32, epochs=10, validation_data=(X_val, y_age_val))
# Out:
# Epoch 1/5
# 625/625 [==============================] - 330s 526ms/step - loss: 9.0064 - accuracy: 0.0399 - val_loss: 9.7720 - val_accuracy: 0.0415
# Epoch 2/5
# 625/625 [==============================] - 312s 499ms/step - loss: 8.6876 - accuracy: 0.0399 - val_loss: 10.3730 - val_accuracy: 0.0448
# Epoch 3/5
# 625/625 [==============================] - 312s 499ms/step - loss: 8.2346 - accuracy: 0.0430 - val_loss: 9.9231 - val_accuracy: 0.0402
# Epoch 4/5
# 625/625 [==============================] - 307s 491ms/step - loss: 7.9487 - accuracy: 0.0426 - val_loss: 9.5475 - val_accuracy: 0.0425
# Epoch 5/5
# 625/625 [==============================] - 305s 489ms/step - loss: 7.6431 - accuracy: 0.0427 - val_loss: 9.9988 - val_accuracy: 0.0472

# %%
from tensorflow.keras.models import load_model
model.save('AgeRecognitionModel_v4.keras')

# %%
# plot results for age
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
def get_image_features(image, width, height):
  img = load_img(image)
  img = img.resize((width, height), Image.LANCZOS)
  img = np.array(img)
  img = img.reshape(1, width, height, 3)
  img = img / 255.0
  return img

# %%
img_to_test = 'FaceRecognition/CamData/data/test/images/00bf6f4c-7fdd-11ee-9103-ec773ba9cb5a.jpg'
features = get_image_features(img_to_test, input_width, input_height)
pred = model.predict(features)
age = round(pred[0][0])

plt.title(f'Predicted Age: {age}')
plt.axis('off')
plt.imshow(np.array(load_img(img_to_test)))
# Out:
# 1/1 [==============================] - 0s 90ms/step
