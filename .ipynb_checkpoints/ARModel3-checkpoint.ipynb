# %%
import tensorflow as tf
from tensorflow.keras.utils import load_img
from keras.models import Sequential, Model
from keras.layers import Dense, Conv2D, Dropout, Flatten, MaxPooling2D, Input
import numpy as np
import random
import matplotlib.pyplot as plt
import os 
#import seaborn as sns
import warnings 
from tqdm.notebook import tqdm 
import pandas as pd 
# %matplotlib inline

# %%
BASE_DIR = 'C:\\Users\\micha\\GitRepos\\AgeRecognition(ML)\\UTKFace'

# %%
train_labels = []
train_paths = []

train_filenames = os.listdir(os.path.join(BASE_DIR, "Train"))
random.shuffle(train_filenames)

train_filenames[0]
# Out:
# '18_1_0_20170109212425897.jpg.chip.jpg'

# %%
val_labels = []
val_paths = []

val_filenames = os.listdir(os.path.join(BASE_DIR, "Val"))
random.shuffle(val_filenames)

val_filenames[0]
# Out:
# '28_1_2_20170116165530274.jpg.chip.jpg'

# %%
test_labels = []
test_paths = []

test_filenames = os.listdir(os.path.join(BASE_DIR, "Test"))
random.shuffle(test_filenames)

test_filenames[0]
# Out:
# '26_0_1_20170117170851628.jpg.chip.jpg'

# %%
def get_paths_and_labels(image_filenames, age_labels, image_paths, folder):
    for image in tqdm(image_filenames):
        image_path = os.path.join(BASE_DIR, folder, image)
        img_components = image.split('_')
    
        if img_components[0] == '.ipynb':
            continue
        age_label = int(img_components[0])
        
        # Append the image_path, age_label, and gender_label
        age_labels.append(age_label)
        image_paths.append(image_path)

# %%
get_paths_and_labels(train_filenames, train_labels, train_paths, "Train")
get_paths_and_labels(val_filenames, val_labels, val_paths, "Val")
get_paths_and_labels(test_filenames, test_labels, test_paths, "Test")
# Out:
#   0%|          | 0/16596 [00:00<?, ?it/s]
#   0%|          | 0/3556 [00:00<?, ?it/s]
#   0%|          | 0/3556 [00:00<?, ?it/s]

# %%
print(f'Number of age_labels: {len(train_labels)}, Number of image_paths: {len(train_paths)}')
# Out:
# Number of age_labels: 16596, Number of image_paths: 16596

# %%
train_df = pd.DataFrame()
train_df['image_path'], train_df['age'] = train_paths, train_labels
train_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   18
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   35
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   26
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   32
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   26

# %%
val_df = pd.DataFrame()
val_df['image_path'], val_df['age'] = val_paths, val_labels
val_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   28
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   31
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...    4
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   84
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   26

# %%
test_df = pd.DataFrame()
test_df['image_path'], test_df['age'] = test_paths, test_labels
test_df.head(5)
# Out:
#                                           image_path  age
# 0  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   26
# 1  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   32
# 2  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   43
# 3  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   23
# 4  C:\Users\micha\GitRepos\AgeRecognition(ML)\UTK...   16

# %%
from PIL import Image

rand_index = random.randint(0, len(val_paths))
age = val_df['age'][rand_index]
IMG = Image.open(val_df['image_path'][rand_index])
plt.title(f'Age: {age}')
plt.axis('off')
plt.imshow(IMG)

# %%
plt.figure(figsize=(20, 20))
samples = train_df.iloc[0:16]

for index, sample, age in samples.itertuples():
    plt.subplot(4, 4, index + 1)
    img = load_img(sample)
    img = np.array(img)
    plt.axis('off')
    plt.title(f'Age: {age}')
    plt.imshow(img)

# %%
input_width = 180
input_height = 180

# %%
def extract_image_features(images, width, height):
    features = list()

    for image in tqdm(images):
        img = load_img(image)
        img = img.resize((width, height), Image.LANCZOS)
        img = np.array(img)
        features.append(img)

    features = np.array(features)
    features = features.reshape(len(features), width, height, 3)
    return features

# %%
X_train = extract_image_features(train_df['image_path'], input_width, input_height)
X_val = extract_image_features(val_df['image_path'], input_width, input_height)
X_test = extract_image_features(test_df['image_path'], input_width, input_height)
# Out:
#   0%|          | 0/16596 [00:00<?, ?it/s]
#   0%|          | 0/3556 [00:00<?, ?it/s]
#   0%|          | 0/3556 [00:00<?, ?it/s]

# %%
X_train.shape
# Out:
# (16596, 180, 180, 3)

# %%
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
y_age_train = np.array(train_df['age'])
y_age_val = np.array(val_df['age'])
y_age_test = np.array(test_df['age'])

# %%
input_shape = (input_width, input_height, 3)

# %%
inputs = Input((input_shape))
conv_1 = Conv2D(32, kernel_size=(3, 3), activation='relu')(inputs)
max_1 = MaxPooling2D(pool_size=(2, 2))(conv_1)
conv_2 = Conv2D(64, kernel_size=(3, 3), activation='relu')(max_1)
max_2 = MaxPooling2D(pool_size=(2, 2))(conv_2)
conv_3 = Conv2D(128, kernel_size=(3, 3), activation='relu')(max_2)
max_3 = MaxPooling2D(pool_size=(2, 2))(conv_3)
conv_4 = Conv2D(256, kernel_size=(3, 3), activation='relu')(max_3)
max_4 = MaxPooling2D(pool_size=(2, 2))(conv_4)

flatten = Flatten()(max_4)

dense = Dense(256, activation='relu')(flatten)
dropout = Dropout(0.3)(dense)

output = Dense(1, activation='relu', name='age_out')(dropout)

model = Model(inputs=[inputs], outputs=[output])

model.compile(loss='mae',
              optimizer='adam', metrics=['accuracy'])

# mlflow.log_metric("test_rmse", 10) # error
# mlflow.sklearn.log_model(model, "models")

# %%
history = model.fit(x=X_train, y=y_age_train,
                    batch_size=32, epochs=10, validation_data=(X_val, y_age_val))
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 history = model.fit(x=X_train, y=y_age_train,
#       2                     batch_size=32, epochs=10, validation_data=(X_val, y_age_val))
#
# File ~\GitRepos\AgeRecognition(ML)\my_env\Lib\site-packages\keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\GitRepos\AgeRecognition(ML)\my_env\Lib\site-packages\tensorflow\python\framework\constant_op.py:102, in convert_to_eager_tensor(value, ctx, dtype)
#     100     dtype = dtypes.as_dtype(dtype).as_datatype_enum
#     101 ctx.ensure_initialized()
# --> 102 return ops.EagerTensor(value, ctx.device_name, dtype)
#
# MemoryError: Unable to allocate 6.01 GiB for an array with shape (16596, 180, 180, 3) and data type float32

# %%
from tensorflow.keras.models import load_model
model.save('AgeRecognitionModel_v2.keras')

# %%
# plot results for age
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(len(loss))

plt.plot(epochs, loss, 'b', label='Training Loss')
plt.plot(epochs, val_loss, 'r', label='Validation Loss')
plt.title('Loss Graph')
plt.legend()
plt.show()

# %%
def get_image_features(image, width, height):
  img = load_img(image)
  img = img.resize((width, height), Image.LANCZOS)
  img = np.array(img)
  img = img.reshape(1, width, height, 3)
  img = img / 255.0
  return img

# %%
img_to_test = 'FaceRecognition/CamData/data/test/images/00bf6f4c-7fdd-11ee-9103-ec773ba9cb5a.jpg'
features = get_image_features(img_to_test, input_width, input_height)
pred = model.predict(features)
age = round(pred[0][0])

plt.title(f'Predicted Age: {age}')
plt.axis('off')
plt.imshow(np.array(load_img(img_to_test)))
# Out:
# 1/1 [==============================] - 0s 416ms/step
